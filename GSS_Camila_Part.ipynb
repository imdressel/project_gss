# %% [markdown]
# <a href="https://colab.research.google.com/github/imdressel/project_gss17/blob/main/GSS_Camila_Part.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/imdressel/project_gss17
# Out:
# Cloning into 'project_gss17'...
# remote: Enumerating objects: 90, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 90 (delta 24), reused 7 (delta 4), pack-reused 52
# Receiving objects: 100% (90/90), 24.62 MiB | 23.48 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
# – CHILDS
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/content/project_gss17/gss_data_20182022.csv')

# %%
df.head()
# Out:
#    year  id        marital  hrs1  conrinc  childs                    meovrwrk
# 0  1994   4        married  32.0  22004.0     3.0                         NaN
# 1  1994   5  never married  20.0      NaN     0.0  neither agree nor disagree
# 2  1994   6  never married  20.0  13203.0     0.0                    disagree
# 3  1994   7        widowed  35.0  27872.0     4.0                         NaN
# 4  1994   8  never married  45.0  13203.0     1.0              strongly agree

# %%
df['childs'].describe()
# Out:
# count    5877.000000
# mean        1.784584
# std         1.672531
# min         0.000000
# 25%         0.000000
# 50%         2.000000
# 75%         3.000000
# max         8.000000
# Name: childs, dtype: float64

# %%
childs = df['childs']
print(childs.unique())
print(childs.dtype)
# Out:
# [ 0.  3.  2.  6.  4.  1.  5.  7. nan  8.]
# float64

# %%
sns.histplot(childs)
plt.xticks(rotation=90)
plt.show()

# %%
pd.crosstab(df['childs'],df['meovrwrk'],margins=True)
# Out:
# meovrwrk  agree  disagree  neither agree nor disagree  strongly agree  \
# childs
# 0.0         434       304                         271              75
# 1.0         227       140                         122              58
# 2.0         416       262                         233              83
# 3.0         237       161                         131              57
# 4.0         104        80                          45              27
# 5.0          44        24                          21              19
# 6.0          30        19                           5               3
# 7.0          17        10                           3               2
# 8.0          14         7                           7              10
# All        1523      1007                         838             334
#
# meovrwrk  strongly disagree   All
# childs
# 0.0                      61  1145
# 1.0                      37   584
# 2.0                      43  1037
# 3.0                      29   615
# 4.0                      11   267
# 5.0                       2   110
# 6.0                       3    60
# 7.0                       2    34
# 8.0                       2    40
# All                     190  3892

# %%
pd.crosstab(df['childs'],df['meovrwrk'],margins=True, normalize=True)
# Out:
# meovrwrk     agree  disagree  neither agree nor disagree  strongly agree  \
# childs
# 0.0       0.111511  0.078109                    0.069630        0.019270
# 1.0       0.058325  0.035971                    0.031346        0.014902
# 2.0       0.106886  0.067318                    0.059866        0.021326
# 3.0       0.060894  0.041367                    0.033659        0.014645
# 4.0       0.026721  0.020555                    0.011562        0.006937
# 5.0       0.011305  0.006166                    0.005396        0.004882
# 6.0       0.007708  0.004882                    0.001285        0.000771
# 7.0       0.004368  0.002569                    0.000771        0.000514
# 8.0       0.003597  0.001799                    0.001799        0.002569
# All       0.391316  0.258736                    0.215313        0.085817
#
# meovrwrk  strongly disagree       All
# childs
# 0.0                0.015673  0.294193
# 1.0                0.009507  0.150051
# 2.0                0.011048  0.266444
# 3.0                0.007451  0.158016
# 4.0                0.002826  0.068602
# 5.0                0.000514  0.028263
# 6.0                0.000771  0.015416
# 7.0                0.000514  0.008736
# 8.0                0.000514  0.010277
# All                0.048818  1.000000

# %%
pd.crosstab(df['childs'],df['marital'],margins=True, normalize=True)
# Out:
# marital  divorced   married  never married  separated   widowed       All
# childs
# 0.0      0.025584  0.064472       0.199215   0.003411  0.008699  0.301382
# 1.0      0.032065  0.067201       0.039059   0.003582  0.010063  0.151970
# 2.0      0.053386  0.149412       0.027972   0.008528  0.022344  0.261641
# 3.0      0.033089  0.077605       0.018250   0.007334  0.017397  0.153676
# 4.0      0.015009  0.033771       0.006993   0.003752  0.010404  0.069930
# 5.0      0.006481  0.012451       0.004435   0.001364  0.004093  0.028825
# 6.0      0.004435  0.006652       0.001194   0.000682  0.002047  0.015009
# 7.0      0.001194  0.003752       0.001023   0.000512  0.001535  0.008016
# 8.0      0.000853  0.003411       0.003241   0.001023  0.001023  0.009551
# All      0.172096  0.418728       0.301382   0.030189  0.077605  1.000000

# %%
#Splitting into two years
df2018 = df[df['year']== 2018].copy()
df2022 = df[df['year']== 2022].copy()

# %% [markdown]
# # Number of Kids vs. Marital Status

# %%
#Grouped Histogram of Number of Kids vs. Marital Status
sns.histplot(data=df,x='childs',hue='marital',stat='proportion', multiple='stack', palette='Dark2')
plt.title('Number of Kids vs. Marital Status')
plt.xlabel('Number of Kids')
plt.ylabel('Marital Status')
plt.show()

# %% [markdown]
# # Number of Kids vs. Men Prioritizing Work 2018 vs. 2022

# %%
#Grouped Histogram of Number of Kids vs. Men Prioritizing Work 2018
df2018['meovrwrk'] = pd.Categorical(df2018['meovrwrk'],categories=["strongly agree","agree","neither agree nor disagree","disagree","strongly disagree"],ordered=True)
sns.histplot(data=df2018,x='meovrwrk',hue='childs',stat='proportion', multiple='stack', palette='Dark2')
plt.title('Number of Kids vs. Men Prioritizing Work 2018')
plt.xlabel('Men Prioritizing Work')
plt.ylabel('Number of Kids')
plt.xticks(rotation=45)
plt.show()

# %%
#Grouped Histogram of Number of Kids vs. Men Prioritizing Work 2022
df2022['meovrwrk'] = pd.Categorical(df2022['meovrwrk'],categories=["strongly agree","agree","neither agree nor disagree","disagree","strongly disagree"],ordered=True)
sns.histplot(data=df2022,x='meovrwrk',hue='childs',stat='proportion', multiple='stack', palette='Dark2')
plt.title('Number of Kids vs. Men Prioritizing Work 2018')
plt.xlabel('Men Prioritizing Work')
plt.ylabel('Number of Kids')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Number of Kids vs. Hours Worked 2018 vs. 2022

# %%
#Cross-tabbing Number of Kids
pd.crosstab(df18['conrinc'], df18['marital'],margins=True,normalize=True)
