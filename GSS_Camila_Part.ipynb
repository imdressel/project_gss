# %% [markdown]
# <a href="https://colab.research.google.com/github/imdressel/project_gss17/blob/main/GSS_Camila_Part.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# – CHILDS

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('./project_gss17/gss_data_v2.csv')

# %%
df.head()
# Out:
#    year  id        marital  hrs1  conrinc  childs                    meovrwrk
# 0  1994   4        married  32.0  22004.0     3.0                         NaN
# 1  1994   5  never married  20.0      NaN     0.0  neither agree nor disagree
# 2  1994   6  never married  20.0  13203.0     0.0                    disagree
# 3  1994   7        widowed  35.0  27872.0     4.0                         NaN
# 4  1994   8  never married  45.0  13203.0     1.0              strongly agree

# %%
df['childs'].describe()
# Out:
# count    42841.000000
# mean         1.828272
# std          1.661853
# min          0.000000
# 25%          0.000000
# 50%          2.000000
# 75%          3.000000
# max          8.000000
# Name: childs, dtype: float64

# %%
childs = df['childs']
print(childs.unique())
print(childs.dtype)
# Out:
# [ 3.  0.  4.  1.  6.  2.  8.  7.  5. nan]
# float64

# %%
sns.histplot(childs)
plt.xticks(rotation=90)
plt.show()

# %%
pd.crosstab(df['childs'],df['meovrwrk'],margins=True)
# Out:
# meovrwrk  agree  disagree  neither agree nor disagree  strongly agree  \
# childs
# 0.0        2744      1511                        1319             524
# 1.0        1502       896                         665             355
# 2.0        2749      1357                        1086             601
# 3.0        1591       827                         598             372
# 4.0         764       398                         279             189
# 5.0         324       144                         113              85
# 6.0         164        86                          42              44
# 7.0          74        44                          23              23
# 8.0          80        45                          31              38
# All        9992      5308                        4156            2231
#
# meovrwrk  strongly disagree    All
# childs
# 0.0                     239   6337
# 1.0                     155   3573
# 2.0                     193   5986
# 3.0                     133   3521
# 4.0                      64   1694
# 5.0                      23    689
# 6.0                      14    350
# 7.0                       6    170
# 8.0                       8    202
# All                     835  22522
